# %%
import sqlite3

# %%
sqliteConnection = sqlite3.connect('Demo.db')

# %%
cursor = sqliteConnection.cursor()

sql = """SELECT * FROM emp"""
cursor.execute(sql)
records = cursor.fetchall()

for data in records:
  print(data)
# Out:
# (2, 25, 'bihar')
# (4, 19, 'hyderabad')

# %%
pip install mysql-connector-python

# %%
sqlcmd = """CREATE TABLE emp(id INTEGER , age INTEGER, address VARCHAR(20));"""


cursor.execute(sqlcmd)

# %%
sqlcmd = """drop table emp"""
cursor.execute(sqlcmd)

# %%
sqlcmd = """INSERT INTO emp VALUES (2, 25, "bihar");"""
cursor.execute(sqlcmd)

sqlcmd = """INSERT INTO emp VALUES (4, 19, "hyderabad");"""
cursor.execute(sqlcmd)

sqliteConnection.commit()

# %%
# Out:
# SELECT * FROM emp
