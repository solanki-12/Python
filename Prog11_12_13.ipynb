# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1381f48b-3f83-45e5-86b0-e8b85377c0fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1381f48b-3f83-45e5-86b0-e8b85377c0fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# importing the csv module
import csv

# field names
columnsName = ['ItemName', 'Item Code', 'Item price']

# data rows of csv file
rows = [ ['Paneer Roll', '23', '80/-'],
		['Chilli Potato', '56', '90/-'],
		['Paneer Momos', '76', '60/-'],
		['French Fries', '12', '100/-', ]]


filename = "test.csv"

with open(filename, 'w') as csvfile:

	# creating a csv writer object
	csvwriter = csv.writer(csvfile)
	
	csvwriter.writerow(columnsName)

	csvwriter.writerows(rows)

# %% [markdown]
# Q.2. Write script to work like a SQL SELECT statement for internal Data Structure.

# %%
pip install mysql-connector-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 23.5 MB 77.8 MB/s
# ...

# %%
import sqlite3
import mysql.connector


sqliteConnection = sqlite3.connect('test.db')


cursorobj = sqliteConnection.cursor()

sql_command = """CREATE TABLE FoodItem (
itemCode INTEGER PRIMARY KEY,
itemName VARCHAR(20),
itemPrice INTEGER(20));"""


cursorobj.execute(sql_command)

# %%
sqliteConnection = sqlite3.connect('test.db')
sql_command = """INSERT INTO FoodItem VALUES (23, "ChilliPanner",
80);"""

sqliteConnection.commit()

cursorobj.execute("SELECT * FROM FoodItem")

outputObj = cursorobj.fetchall()



for i in outputObj:
    print(i)


sqliteConnection.close()

# %%
sqliteConnection = sqlite3.connect('test.db')


cursorobj = sqliteConnection.cursor()

cursorobj.execute("SELECT FROM emp INNER JOIN emp1 ON emp.id=emp1.id")
objff=cursorobj.fetchall()

for i in objff:
  print(i)
